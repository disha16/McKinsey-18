# %%
import numpy
import pandas as pd
import matplotlib as pyplot
path = raw_input("Your CSV file: ")
n = raw_input("Moving Average of:  ")
n = int(n)
df = pd.read_csv(path)
df.set_index('date')
df['value']=df['value'].rolling(window=n).mean(center=True)
# Out:
# Your CSV file: C:\Users\Rawal Rawal\Desktop\data.csv
# Moving Average of:  4
# Second Order for Moving Average:  1
