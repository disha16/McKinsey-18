# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
from stldecompose import decompose, forecast
from stldecompose.forecast_funcs import (naive,
                                         drift, 
                                         mean, 
                                         seasonal_naive)

obs = pd.read_csv("C:\Users\Rawal Rawal\Desktop\Fremont_Bridge_Hourly_Bicycle_Counts_by_Month_October_2012_to_present.csv")
format = '%m/%d/%Y %H:%M'
obs['Date'] = pd.to_datetime(obs['Date'], format=format)
obs = obs.set_index(pd.DatetimeIndex(obs['Date']))
obs.drop('Fremont Bridge East Sidewalk', axis=1)
stl = decompose(obs['Fremont Bridge West Sidewalk'], period=365)
stl.plot()
