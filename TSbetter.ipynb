# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from numpy import sqrt,log
# %matplotlib inline
df=pd.read_csv("C:\Users\Rawal Rawal\Desktop\Fremont_Bridge_Hourly_Bicycle_Counts_by_Month_October_2012_to_present.csv", index_col='Date', parse_dates=True)
df.columns = ['West', 'East']
df['Total'] = df.eval('West + East')
p = raw_input("Transformation Exponent-->")
q = raw_input("1= power,2=log-   ")

if q==1:
    df.Total = df.Total.map(lambda x : x**p)
else:
    df.Total = df.Total.map(lambda x: log(x+1))
df.Total.plot()
# Out:
# Transformation Exponent-->1/2
# 1= power,2=log-   1
